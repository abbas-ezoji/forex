# %%
import tensorflow as tf
import numpy as np
import progressbar
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.4.0

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from array import array 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
# df=pd.read_csv("BTC-USD.csv")
# df.tail(5)

# %%
import yfinance as yf

stock = yf.Ticker("BTC-USD")
hist = stock.history(period="5y")
hist.tail(10)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-06-27  32287.523438  34656.128906  32071.757812  34649.644531
# 2021-06-28  34679.121094  35219.890625  33902.074219  34434.335938
# 2021-06-29  34475.558594  36542.109375  34252.484375  35867.777344
# 2021-06-30  35908.386719  36074.757812  34086.152344  35040.835938
# 2021-07-01  35035.984375  35035.984375  32883.781250  33572.117188
# 2021-07-02  33549.601562  33939.589844  32770.679688  33897.046875
# 2021-07-03  33854.421875  34909.261719  33402.695312  34668.546875
# 2021-07-04  34665.566406  35937.566406  34396.476562  35287.781250
# 2021-07-05  35284.343750  35284.343750  33213.660156  33746.003906
# 2021-07-06  33763.742188  35038.535156  33759.960938  33831.140625
#
#                  Volume  Dividends  Stock Splits
# Date
# 2021-06-27  35511640894          0             0
# 2021-06-28  33892523752          0             0
# 2021-06-29  37901460044          0             0
# 2021-06-30  34059036099          0             0
# 2021-07-01  37838957079          0             0
# 2021-07-02  38728974942          0             0
# 2021-07-03  24383958643          0             0
# 2021-07-04  24924307911          0             0
# 2021-07-05  26721554282          0             0
# 2021-07-06  25340934144          0             0

# %%
import yfinance as yf

stock = yf.Ticker("ETH-USD")
hist = stock.history(period="5y")
hist.tail(10)
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2021-06-27  1830.996948  1979.958130  1811.245850  1978.894653  19885474742
# 2021-06-28  1981.386475  2139.805420  1963.615479  2079.657471  25514602841
# 2021-06-29  2083.448730  2242.238770  2076.240234  2160.768311  24815124419
# 2021-06-30  2164.216309  2282.989014  2090.760742  2274.547607  25828056268
# 2021-07-01  2274.397461  2274.397461  2081.081055  2113.605469  29061701793
# 2021-07-02  2109.892578  2155.596436  2021.824829  2150.040283  31796212554
# 2021-07-03  2150.834961  2237.567139  2117.590088  2226.114258  17433361641
# 2021-07-04  2226.550293  2384.286865  2190.837646  2321.724121  18787107473
# 2021-07-05  2321.922852  2321.922852  2163.041504  2198.582520  20103794829
# 2021-07-06  2203.929932  2346.294922  2203.929932  2290.361572  19796557824
#
#             Dividends  Stock Splits
# Date
# 2021-06-27          0             0
# 2021-06-28          0             0
# 2021-06-29          0             0
# 2021-06-30          0             0
# 2021-07-01          0             0
# 2021-07-02          0             0
# 2021-07-03          0             0
# 2021-07-04          0             0
# 2021-07-05          0             0
# 2021-07-06          0             0

# %%
df=hist
d=30
ahead=10
n=int(hist.shape[0]*0.8)
training_set = df.iloc[:n, 1:2].values
test_set = df.iloc[n:, 1:2].values

# %%
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

X_train = []
y_train = []
for i in range(d, n-ahead):
    X_train.append(training_set_scaled[i-d:i, 0])
    y_train.append(training_set_scaled[i+ahead, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 13s 82ms/step - loss: 0.0161
# Epoch 2/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0072
# Epoch 3/50
# 45/45 [==============================] - 4s 84ms/step - loss: 0.0052
# Epoch 4/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0039
# Epoch 5/50
# 45/45 [==============================] - 4s 84ms/step - loss: 0.0059
# Epoch 6/50
# 45/45 [==============================] - 4s 85ms/step - loss: 0.0046
# Epoch 7/50
# 45/45 [==============================] - 4s 82ms/step - loss: 0.0047
# Epoch 8/50
# 45/45 [==============================] - 4s 82ms/step - loss: 0.0046
# Epoch 9/50
# 45/45 [==============================] - 4s 85ms/step - loss: 0.0053
# Epoch 10/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0045
# Epoch 11/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0040
# Epoch 12/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0053
# Epoch 13/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0040
# Epoch 14/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0044
# Epoch 15/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0043
# Epoch 16/50
# 45/45 [==============================] - 4s 80ms/step - loss: 0.0040
# Epoch 17/50
# 45/45 [==============================] - 4s 80ms/step - loss: 0.0042
# Epoch 18/50
# 45/45 [==============================] - 4s 80ms/step - loss: 0.0041
# Epoch 19/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0050
# Epoch 20/50
# 29/45 [==================>...........] - ETA: 1s - loss: 0.0031

# %%
model.save("ETH-predict.h5")

# %%
from keras.models import load_model

model = load_model("BTC-predict.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 100)           40800
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 100)           80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 100)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 50)            30200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 50)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 171,651
# Trainable params: 171,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Getting the predicted stock price

dataset_train = df.iloc[:n, 1:2]
dataset_test = df.iloc[n:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - d:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
X_test = []
for i in range(d, inputs.shape[0]):
    X_test.append(inputs[i-d:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (365, 30, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
df['Date']=df.index

# %%
df=df.reset_index(drop=True)
df
# Out:
#              Open         High          Low        Close       Volume  \
# 0       11.696100    11.880200    11.389500    11.471000     12943500
# 1       11.457400    11.517800     9.576260    10.611400     45526900
# 2       10.575800    11.105600    10.280800    10.528900     18137300
# 3       10.535900    10.565800     9.803210    10.109400     15407200
# 4       10.115300    11.524800     9.961260    11.394600     20039800
# ...           ...          ...          ...          ...          ...
# 1818  2164.216309  2282.989014  2090.760742  2274.547607  25828056268
# 1819  2274.397461  2274.397461  2081.081055  2113.605469  29061701793
# 1820  2109.892578  2155.596436  2021.824829  2150.040283  31796212554
# 1821  2150.834961  2237.567139  2117.590088  2226.114258  17433361641
# 1822  2228.898682  2364.710449  2191.963135  2351.750732  18379083776
#
#       Dividends  Stock Splits       Date
# 0             0             0 2016-07-04
# 1             0             0 2016-07-05
# 2             0             0 2016-07-06
# 3             0             0 2016-07-07
# 4             0             0 2016-07-08
# ...         ...           ...        ...
# 1818          0             0 2021-06-30
# 1819          0             0 2021-07-01
# 1820          0             0 2021-07-02
# 1821          0             0 2021-07-03
# 1822          0             0 2021-07-04
#
# [1823 rows x 8 columns]

# %%
plt.plot(df.loc[n:, 'Date'],dataset_test.values, color = 'red', label = 'Real Butcoin Stock Price')
plt.plot(df.loc[n:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted Bitcoin Stock Price')

plt.title('Bitcoin Price Prediction')
plt.xlabel('Time')
plt.ylabel('Bitcoin Price')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Get tomorrow's predicted price

# %%
df
# Out:
#               Open          High           Low         Close       Volume  \
# 0       374.645996    374.950012    368.045013    369.949005     45933400
# 1       370.174011    391.608002    369.993011    389.593994     69285504
# 2       388.898010    391.093994    385.571991    386.549011     43825000
# 3       386.588989    386.631012    372.386993    376.522003     49249300
# 4       376.514008    380.871002    374.903015    376.619995     37076300
# ...            ...           ...           ...           ...          ...
# 1819  34295.933594  34834.707031  32940.187500  34269.523438  65141828798
# 1820  34270.878906  34288.332031  32270.175781  33114.359375  52754542671
# 1821  33114.578125  34638.214844  32384.228516  33537.175781  61400400660
# 1822  33533.199219  35896.882812  33489.218750  35510.289062  63088585433
# 1823  36089.023438  36753.347656  35448.914062  36631.023438  66044252160
#
#       Dividends  Stock Splits       Date
# 0             0             0 2016-02-03
# 1             0             0 2016-02-04
# 2             0             0 2016-02-05
# 3             0             0 2016-02-06
# 4             0             0 2016-02-07
# ...         ...           ...        ...
# 1819          0             0 2021-01-30
# 1820          0             0 2021-01-31
# 1821          0             0 2021-02-01
# 1822          0             0 2021-02-02
# 1823          0             0 2021-02-03
#
# [1824 rows x 8 columns]

# %%
## Add a dummy row at the end. This will not be used to predict. 

df.loc[len(df)]=df.loc[len(df)-1]

# %%
df
# Out:
#               Open          High           Low         Close       Volume  \
# 0       374.645996    374.950012    368.045013    369.949005     45933400
# 1       370.174011    391.608002    369.993011    389.593994     69285504
# 2       388.898010    391.093994    385.571991    386.549011     43825000
# 3       386.588989    386.631012    372.386993    376.522003     49249300
# 4       376.514008    380.871002    374.903015    376.619995     37076300
# ...            ...           ...           ...           ...          ...
# 1820  34270.878906  34288.332031  32270.175781  33114.359375  52754542671
# 1821  33114.578125  34638.214844  32384.228516  33537.175781  61400400660
# 1822  33533.199219  35896.882812  33489.218750  35510.289062  63088585433
# 1823  36089.023438  36753.347656  35448.914062  36631.023438  66044252160
# 1824  36089.023438  36753.347656  35448.914062  36631.023438  66044252160
#
#       Dividends  Stock Splits       Date
# 0             0             0 2016-02-03
# 1             0             0 2016-02-04
# 2             0             0 2016-02-05
# 3             0             0 2016-02-06
# 4             0             0 2016-02-07
# ...         ...           ...        ...
# 1820          0             0 2021-01-31
# 1821          0             0 2021-02-01
# 1822          0             0 2021-02-02
# 1823          0             0 2021-02-03
# 1824          0             0 2021-02-03
#
# [1825 rows x 8 columns]

# %%
# Getting the predicted stock price

dataset_train = df.iloc[:n, 1:2]
dataset_test = df.iloc[n:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - d:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
X_test = []
for i in range(d, inputs.shape[0]):
    X_test.append(inputs[i-d:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (366, 30, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
float(predicted_stock_price[-1])
# Out:
# 23106.318359375

# %%
print("Tomorrow's predicted price = $", float(predicted_stock_price[-1]))
# Out:
# Tomorrow's predicted price = $ 23106.318359375
