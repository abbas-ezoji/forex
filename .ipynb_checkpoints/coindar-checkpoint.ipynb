# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
base_url = 'https://coindar.org/en/coin/elrond'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
r = requests.get(base_url, headers=headers)
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <!--
# $$\   $$\  $$$$$$\  $$$$$$$\  $$\
# $$ |  $$ |$$  __$$\ $$  __$$\ $$ |
# $$ |  $$ |$$ /  $$ |$$ |  $$ |$$ |
# $$$$$$$$ |$$ |  $$ |$$ |  $$ |$$ |
# $$  __$$ |$$ |  $$ |$$ |  $$ |$$ |
# $$ |  $$ |$$ |  $$ |$$ |  $$ |$$ |
# $$ |  $$ | $$$$$$  |$$$$$$$  |$$$$$$$$\
# \__|  \__| \______/ \_______/ \________|
# !-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Elrond Events, News &amp; Roadmap: Hard Fork, Halving, Release, Airdrop — Coindar</title>
# <link href="https://coindar.org/en/coin/elrond" rel="canonical"/>
# <link href="https://coindar.org/en/coin/elrond" hreflang="en" rel="alternate"/>
# <link href="https://coindar.org/ru/coin/elrond" hreflang="ru" rel="alternate"/>
# <meta content="yes" name="apple-mobile-web-app-enabled"/>
# <meta content="Coindar" name="apple-mobile-web-app-title"/>
# <meta content="initial-scale = 1, user-scalable = no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/images/icons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/images/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/images/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.en.json" rel="manifest"/>
# <script async="" src="/scripts/pwacompat.min.js"></script>
# <link color="#5bbad5" href="/images/icons/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/images/icons/favicon.ico" rel="shortcut icon"/>
# <meta content="Coindar" name="application-name"/>
# <meta content="#2b5797" name="msapplication-TileColor"/>
# <meta content="browserconfig.xml" name="msapplication-config"/>
# <meta content="/?source=pwa" name="msapplication-starturl">
# <meta content="#ffffff" name="theme-color"/>
# <meta content="https://coindar.org/en/coin/elrond" property="og:url">
# <meta content="https://coindar.org/en/coin/elrond" name="twitter:url">
# <meta content="Elrond (EGLD) roadmap, news &amp; upcoming events: hard fork, halving, release, airdrop, listing on Binance and others." name="description">
# <meta content="cryptocurrency crypto events elrond egld update coin altcoin listing meetup burn release hard fork soft fork roadmap halving airdrop" name="keywords">
# <meta content="Elrond Events, News &amp; Roadmap: Hard Fork, Halving, Release, Airdrop" property="og:title">
# <meta content="Elrond (EGLD) roadmap, news &amp; upcoming events: hard fork, halving, release, airdrop, listing on Binance and others." property="og:description">
# <meta content="https://coindar.org/images/coins/elrond/64x64.png" property="og:image"/>
# <meta content="image/jpg" property="og:image:type">
# <meta content="64" property="og:image:width">
# <meta content="64" property="og:image:height">
# <meta content="business.business" property="og:type"/>
# <meta content="Elrond Events, News &amp; Roadmap: Hard Fork, Halving, Release, Airdrop" name="twitter:title"/>
# <meta content="Elrond (EGLD) roadmap, news &amp; upcoming events: hard fork, halving, release, airdrop, listing on Binance and others." name="twitter:description"/>
# <meta content="https://coindar.org/images/coins/elrond/64x64.png" name="twitter:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@coindar_" name="twitter:site"/>
# <link href="/less/light?v=33" rel="stylesheet">
# <link href="/css/fonts.css" rel="stylesheet">
# <link href="/fonts/awesome/css/all.css" rel="stylesheet">
# <link href="/less/mobile?v=29" media="(max-width: 1023px)" rel="stylesheet">
# <link href="/css/flags.min.css" rel="stylesheet">
# <script>(function (d, w, c) { (w[c] = w[c] || []).push(function () { try { w.yaCounter46194717 = new Ya.Metrika({ id: 46194717, clickmap: true, trackLinks: true, accurateTrackBounce: true, webvisor: true }); } catch (e) { } }); var n = d.getElementsByTagName("script")[0], s = d.createElement("script"), f = function () { n.parentNode.insertBefore(s, n); }; s.type = "text/javascript"; s.async = true; s.src = "https://mc.yandex.ru/metrika/watch.js"; if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); } })(document, window, "yandex_metrika_callbacks");</script>
# <!-- Global Site Tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-107733489-1"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-107733489-1');
#     </script>
# <script src="https://coinzillatag.com/lib/sticky.js"></script>
# <script>window.coinzilla_sticky = window.coinzilla_sticky || []; function czilla() { coinzilla_sticky.push(arguments); } czilla('273825ba3e91a12445');</script>
# </link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <noscript><div><img alt="yandex" src="https://mc.yandex.ru/watch/46194717" style="position:absolute; left:-9999px;"/></div></noscript>
# <div class="content">
# <div class="block-header">
# <div class="header">
# <div class="nav">
# <div class="logo">
# <div class="bar">
# <a href="javascript:void(0)" onclick="showMainMenu()">
# <i class="far fa-bars"></i>
# </a>
# </div>
# <a href="/">
# <div class="image">
# <img alt="Coindar" src="/images/blank.gif"/>
# </div>
# <div class="text">
#                                     Coindar
#                                 </div>
# </a>
# </div>
# <div class="panel-cats">
# <div class="menu-item" id="navEvents" onclick="return showMenuFull('Events')"><a class="a-menu a-sub" href="/" id="aEvents">Calendar</a></div>
# <div class="menu-sub-full" id="EventsSub">
# <div class="block-container">
# <div class="item">
# <h2><a href="/en">Calendar</a></h2>
# <p>All current events of cryptocurrencies and search on them</p>
# </div>
# <div class="item">
# <h2><a href="/en/add">Add event</a></h2>
# <p>Contribute to the development of the service</p>
# </div>
# <div class="item">
# <h2><a href="/en/account/dashboard">Favorites</a></h2>
# <p>Events and favorite coins rates</p>
# </div>
# <div class="item">
# <h2><a href="/en/account/notifier">Notifier</a></h2>
# <p>Delivery of notifications about new events of your coins using mail, Telegram, Web Push</p>
# </div>
# <div class="item">
# <h2><a href="https://listedon.org/en" target="_blank">Listing Monitoring <i class="fas fa-external-link"></i></a></h2>
# <p>New coin listings and trading pairs on cryptocurrency exchanges</p>
# </div>
# </div>
# </div>
# <div class="menu-item"><a class="a-menu" href="/en/synergies/"><i class="fad fa-atom-alt"></i> Synergies</a></div>
# <div class="menu-item"><a class="a-menu" href="/en/coins/">Coins</a></div>
# <div class="menu-item"><a class="a-menu" href="/en/articles/">Articles</a></div>
# <div class="menu-item"><a class="a-menu" href="/en/special/bingbon">Copy Trading</a></div>
# <div class="menu-social">
# <a class="a-menu-soc" href="tg://resolve?domain=coindar" target="_blank"><i class="fab fa-telegram"></i></a>
# <a class="a-menu-soc" href="tg://resolve?domain=coindar_blog" target="_blank"><i class="fab fa-telegram blue"></i></a>
# <a class="a-menu-soc" href="https://twitter.com/coindar_" target="_blank"><i class="fab fa-twitter"></i></a>
# <a class="a-menu-soc" href="https://facebook.com/coindar" target="_blank"><i class="fab fa-facebook"></i></a>
# </div>
# </div>
# <div class="panel-right">
# <div class="p-right">
# <div class="menu-item"><a class="a-menu" href="/en/account/signin" onclick="return showAuth()">Sign in</a></div>
# <div class="menu-item">
# <a class="a-menu" id="switchTheme"><i class="fad fa-lightbulb-slash"></i> <span>Dark mode</span></a>
# </div>
# <div class="menu-item" id="navLanguage" onclick="return showMenu('Language')">
# <a class="a-menu" href="https://coindar.org" id="aLanguage"><img alt="Language" class="flag flag-gb" src="/images/blank.gif"/><span>Language</span></a>
# <div class="menu-sub" id="LanguageSub">
# <div>
# <a class="a-lang" href="https://coindar.org/en/coin/elrond" onclick="event.stopPropagation()">English</a>
# <a class="a-lang" href="https://coindar.org/ru/coin/elrond" onclick="event.stopPropagation()">Русский</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="block-adv">
# <script async="" src="https://coinzillatag.com/lib/display.js"></script>
# <div class="coinzilla" data-zone="C-460485a148fbd9c91d"></div>
# <script>
#             window.coinzilla_display = window.coinzilla_display || [];
#             var c_display_preferences = {};
#             c_display_preferences.zone = "460485a148fbd9c91d";
#             c_display_preferences.width = "728";
#             c_display_preferences.height = "90";
#             coinzilla_display.push(c_display_preferences);
#         </script>
# </div>
# <div class="block-main">
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "Product",
#     "name": "Elrond",
#     "image": "https://coindar.org/images/coins/elrond/64x64.png"
# ,"offers": {"@type": "Offer","price": "63.830000000","priceCurrency": "USD"}    }
# </script>
# <div class="page-title coin-title w100">
# <div class="coin-sub-title">
# <img alt="Elrond" src="/images/coins/elrond/32x32.png"/>
# <h1>
#
#             Elrond Events, News &amp; Roadmap: Hard Fork, Halving, Release, Airdrop
#
#         </h1>
# </div>
# <div class="tool-star" onclick="toFavorite(11268, 'coin')">
# <i class="fas fa-star" id="coinFavIco"></i>
# <i class="fav" id="coinFavCount" style="">6</i>
# <input id="coinFavValue" type="hidden" value="0"/>
# </div>
# </div>
# <div class="block-break">
# <div class="block-container block-coin">
# <div class="coin-top-cont" style="">
# <div class="table-info">
# <div class="item">
# <div class="cap"><strong>Price, BTC</strong></div>
# <div class="val">0.001958937</div>
# </div>
# <div class="item">
# <div class="cap">ETH</div>
# <div class="val">0.049330719</div>
# </div>
# <div class="item">
# <div class="cap">USD</div>
# <div class="val">
# 63.83                </div>
# </div>
# <div class="item">
# <div class="cap"><strong>1h</strong></div>
# <div class="val"><span class="red">-0.13%</span></div>
# </div>
# <div class="item">
# <div class="cap">24h</div>
# <div class="val"><span class="red">-5.22%</span></div>
# </div>
# <div class="item">
# <div class="cap">7d</div>
# <div class="val"><span class="green">72.17%</span></div>
# </div>
# <div class="item">
# <div class="cap"><strong>24h volume, BTC</strong></div>
# <div class="val">5.11<span class="short-num">K</span></div>
# </div>
# <div class="item">
# <div class="cap">USD</div>
# <div class="val">166<span class="short-num">M</span></div>
# </div>
# </div>
# </div>
# <div class="coin-info">
# <div class="info_">
# <div class="block">
# <div class="rank">
# <strong>Market Cap</strong><br/> 1.09<span class="short-num">B</span> USD<br/>
#                             CMC Rank: <span class="fro">43</span><br/>
# Circulating supply: <span class="fro">17084542</span><br/>
# <span class="sid">Coindar Social Index:</span> —<br/>
# </div>
# </div>
# </div>
# <div class="info_">
# <div class="block">
# <strong>Links</strong>
# <a href="https://coingecko.com/en/coins/elrond-erd-2" rel="nofollow" target="_blank"><i class="fas fa-link"></i> CoinGecko</a>
# </div>
# </div>
# </div>
# <div class="event-charts" id="eventCharts">
# <div class="dyn-menu">
# <a class="dm menu-sel" href="javascript:void(0)" id="showChart0">Event date</a> <a class="dm" href="javascript:void(0)" id="showChart1">Event added date </a>
# </div>
# <div id="coinChart"></div>
# <div id="coinChartPub"></div>
# </div>
# <script src="/scripts/amcharts/amcharts.js"></script>
# <script src="/scripts/amcharts/serial.js"></script>
# <script src="/scripts/amcharts/amstock.js"></script>
# <script src="/scripts/amcharts/plugins/export/export.min.js"></script>
# <link href="/scripts/amcharts/plugins/export/export.css" media="all" rel="stylesheet" type="text/css">
# <script src="/scripts/amcharts/themes/light.js"></script>
# <script type="text/javascript">
#         var chartData = [{'date': new Date(2021,01-1,31), 'value': 63.830000000}];
#         var chartEvents = [{'date': new Date(2021,01-1,07), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Gate.io', 'url': '/en/event/elrond-egld-listing-on-gateio-36562'},{'date': new Date(2020,12-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on eToroX', 'url': '/en/event/elrond-egld-listing-on-etorox-35004'},{'date': new Date(2020,10-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Tokocrypto', 'url': '/en/event/elrond-egld-listing-on-tokocrypto-33412'},{'date': new Date(2020,10-1,16), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'EGLD & CNTR Rewards Distribution', 'url': '/en/event/elrond-egld-egld-cntr-rewards-distribution-32947'},{'date': new Date(2020,10-1,12), 'type': 'text', 'backgroundColor': '#bab57e', 'borderColor': '#bab57e', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#ada873', 'text': 'Report', 'description': 'Weekly Development Update', 'url': '/en/event/elrond-egld-weekly-development-update-33130'},{'date': new Date(2020,10-1,08), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32997'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Binance Savings Staking', 'url': '/en/event/elrond-egld-binance-savings-staking-32949'},{'date': new Date(2020,09-1,30), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32840'},{'date': new Date(2020,09-1,30), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32851'},{'date': new Date(2020,09-1,24), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Binance.US', 'url': '/en/event/elrond-egld-listing-on-binanceus-32610'},{'date': new Date(2020,09-1,24), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32618'},{'date': new Date(2020,09-1,22), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Bithumb Global', 'url': '/en/event/elrond-egld-listing-on-bithumb-global-31428'},{'date': new Date(2020,09-1,22), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Bithumb Global', 'url': '/en/event/elrond-egld-listing-on-bithumb-global-32564'},{'date': new Date(2020,09-1,16), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Sistemkoin', 'url': '/en/event/elrond-egld-listing-on-sistemkoin-32390'},{'date':  ...
#         var chartEvents_pub = [{'date': new Date(2021,01-1,07), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Gate.io', 'url': '/en/event/elrond-egld-listing-on-gateio-36562'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'DeFi Initiatives', 'url': '/en/event/elrond-egld-defi-initiatives-30212'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Privacy Research', 'url': '/en/event/elrond-egld-privacy-research-30213'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Blockchain Interoperability', 'url': '/en/event/elrond-egld-blockchain-interoperability-30214'},{'date': new Date(2020,12-1,16), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on eToroX', 'url': '/en/event/elrond-egld-listing-on-etorox-35004'},{'date': new Date(2020,10-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Tokocrypto', 'url': '/en/event/elrond-egld-listing-on-tokocrypto-33412'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'EGLD & CNTR Rewards Distribution', 'url': '/en/event/elrond-egld-egld-cntr-rewards-distribution-32947'},{'date': new Date(2020,10-1,12), 'type': 'text', 'backgroundColor': '#bab57e', 'borderColor': '#bab57e', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#ada873', 'text': 'Report', 'description': 'Weekly Development Update', 'url': '/en/event/elrond-egld-weekly-development-update-33130'},{'date': new Date(2020,10-1,07), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32997'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Binance Savings Staking', 'url': '/en/event/elrond-egld-binance-savings-staking-32949'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#8cbf80', 'borderColor': '#8cbf80', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7db072', 'text': 'Release', 'description': 'Elrond dApp Store', 'url': '/en/event/elrond-egld-elrond-dapp-store-29938'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#c3c27c', 'borderColor': '#c3c27c', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b7b672', 'text': 'Update', 'description': 'Elrond Digital Identity', 'url': '/en/event/elrond-egld-elrond-digital-identity-30210'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#8cbf80', 'borderColor': '#8cbf80', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7db072', 'text': 'Release', 'description': 'Name Service', 'url': '/en/event/elrond-egld-name-service-30211'},{'date': new Date(2020,09-1,29), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32840'},{'date': new Date(2020,09-1,29 ...
# </script>
# <div class="event-stat"><div class="event-stat-cap">During the whole time of <span class="coin_logo" style="background-image: url('/images/coins/elrond/32x32.png')"></span><strong>Elrond</strong> monitoring,  <strong>54&amp;nbspevents</strong> were added:</div> <i class="fad fa-exchange exchange"></i> <strong>16</strong> <strong>exchange</strong> events<br/><i class="fad fa-browser release"></i> <strong>11&amp;nbspreleases</strong><br/> <i class="fad fa-map-marker-question ama"></i> <strong>8</strong> <strong>AMA sessions</strong><br/> <i class="fad fa-calendar general"></i> <strong>5</strong> <strong>general</strong> events<br/><i class="fad fa-sync-alt update"></i> <strong>4&amp;nbspupdates</strong><br/><i class="fad fa-file-chart-pie update"></i> <strong>3&amp;nbspreports</strong><br/><i class="fad fa-handshake-alt partnership"></i> <strong>2&amp;nbsppartnerships</strong><br/> <i class="fad fa-gift contest"></i> <strong>2&amp;nbspcontests</strong><br/> <i class="fad fa-users conference"></i> <strong>1</strong> <strong>conference</strong> participation<br/><i class="fad fa-retweet swap"></i> <strong>1&amp;nbsptoken swap</strong><br/> <i class="fad fa-check-double test"></i> <strong>1</strong> <strong>event</strong> related to testing of new functions<br/></div>
# <div class="loc-menu m25">
# <h2 class="menu-nosel menu-sel" id="showItem1">Upcoming <strong>Elrond</strong> events</h2>
# <i class="menu-nosel" id="showItem2">Past <strong>Elrond</strong> events</i>
# </div>
# <div class="cryptocurrency-events w100">
# <div class="events event-list">
# <div id="eventsFuture">
# <div class="day-cont"> <div class="day">
#                 January 31, 2021
#             </div>
# <div class="event" id="event34865">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue34865" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-maiar-wallet-launch-34865" id="cap34865">
#                         Maiar Wallet Launch
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 month ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event37161">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue37161" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-maiar-launch-37161" id="cap37161">
#                         Maiar Launch
#                     </a>
# </h3>
# <div class="added">
#                     Added yesterday
#
#
#                 </div>
# </div>
# </div>
# </div>
# </div>
# <div id="eventsPast" style="display:none;">
# <div class="day-cont"> <div class="day">
#                 January 7, 2021
#             </div>
# <div class="event" id="event36562">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue36562" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-gateio-36562" id="cap36562">
#                         Listing on <img class="exchange" src="/images/exchanges/gate-io/32x32.png"/>Gate.io
#                     </a>
# </h3>
# <div class="added">
#                     Added 24 days ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 Until December 31, 2020
#             </div>
# <div class="event" id="event30212">
# <div class="tool-events">
# </div>
# <input id="favValue30212" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type general" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=1&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="General">General</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-defi-initiatives-30212" id="cap30212">
#                         DeFi Initiatives
#                     </a>
# </h3>
# <div class="added">
#                     Added 6 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event30213">
# <div class="tool-events">
# </div>
# <input id="favValue30213" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type general" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=1&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="General">General</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-privacy-research-30213" id="cap30213">
#                         Privacy Research
#                     </a>
# </h3>
# <div class="added">
#                     Added 6 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event30214">
# <div class="tool-events">
# </div>
# <input id="favValue30214" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type general" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=1&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="General">General</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-blockchain-interoperability-30214" id="cap30214">
#                         Blockchain Interoperability
#                     </a>
# </h3>
# <div class="added">
#                     Added 6 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 December 23, 2020
#             </div>
# <div class="event" id="event35004">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue35004" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-etorox-35004" id="cap35004">
#                         Listing on <img class="exchange" src="/images/exchanges/etorox/32x32.png"/>eToroX
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 month ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 October 23, 2020
#             </div>
# <div class="event" id="event33412">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue33412" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-tokocrypto-33412" id="cap33412">
#                         Listing on <img class="exchange" src="/images/exchanges/tokocrypto/32x32.png"/>TokoCrypto
#                     </a>
# </h3>
# <div class="added">
#                     Added 3 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 October 16, 2020
#             </div>
# <div class="event" id="event32947">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32947" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type general" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=1&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="General">General</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-egld-cntr-rewards-distribution-32947" id="cap32947">
#                         EGLD &amp; CNTR Rewards Distribution
#                     </a>
# </h3>
# <div class="added">
#                     Added 3 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 October 12, 2020
#             </div>
# <div class="event" id="event33130">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue33130" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type report" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=20&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Report">Report</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-weekly-development-update-33130" id="cap33130">
#                         Weekly Development Update
#                     </a>
# </h3>
# <div class="added">
#                     Added 3 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 October 8, 2020
#             </div>
# <div class="event" id="event32997">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32997" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type ama" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=2&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="AMA">AMA</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-ama-on-periscope-32997" id="cap32997">
#                         AMA on <i class="fab fa-periscope"></i>Periscope
#                     </a>
# </h3>
# <div class="added">
#                     Added 3 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 October 4, 2020
#             </div>
# <div class="event" id="event32949">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32949" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type general" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=1&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="General">General</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-binance-savings-staking-32949" id="cap32949">
#                         Binance Savings Staking
#                     </a>
# </h3>
# <div class="added">
#                     Added 3 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 Until September 30, 2020
#             </div>
# <div class="event" id="event29938">
# <div class="tool-events">
# </div>
# <input id="favValue29938" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-elrond-dapp-store-29938" id="cap29938">
#                         Elrond dApp Store
#                     </a>
# </h3>
# <div class="added">
#                     Added 6 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event30210">
# <div class="tool-events">
# </div>
# <input id="favValue30210" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type update" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=19&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Update">Update</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-elrond-digital-identity-30210" id="cap30210">
#                         Elrond Digital Identity
#                     </a>
# </h3>
# <div class="added">
#                     Added 6 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event30211">
# <div class="tool-events">
# </div>
# <input id="favValue30211" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-name-service-30211" id="cap30211">
#                         Name Service
#                     </a>
# </h3>
# <div class="added">
#                     Added 6 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 30, 2020
#             </div>
# <div class="event" id="event32840">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32840" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-okex-32840" id="cap32840">
#                         Listing on <img class="exchange" src="/images/exchanges/okex/32x32.png"/>OKEx
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event32851">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32851" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-okex-32851" id="cap32851">
#                         Listing on <img class="exchange" src="/images/exchanges/okex/32x32.png"/>OKEx
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 24, 2020
#             </div>
# <div class="event" id="event32610">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32610" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-binanceus-32610" id="cap32610">
#                         Listing on Binance.US
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event32618">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32618" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type ama" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=2&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="AMA">AMA</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-ama-on-periscope-32618" id="cap32618">
#                         AMA on <i class="fab fa-periscope"></i>Periscope
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 22, 2020
#             </div>
# <div class="event" id="event31428">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue31428" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-bithumb-global-31428" id="cap31428">
#                         Listing on <img class="exchange" src="/images/exchanges/bithumb-global/32x32.png"/>Bithumb Global
#                     </a>
# </h3>
# <div class="added">
#                     Added 5 months ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event32564">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32564" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-bithumb-global-32564" id="cap32564">
#                         Listing on <img class="exchange" src="/images/exchanges/bithumb-global/32x32.png"/>Bithumb Global
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 16, 2020
#             </div>
# <div class="event" id="event32390">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32390" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-sistemkoin-32390" id="cap32390">
#                         Listing on <img class="exchange" src="/images/exchanges/sistemkoin/32x32.png"/>Sistemkoin
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 15, 2020
#             </div>
# <div class="event" id="event32298">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32298" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-indodax-32298" id="cap32298">
#                         Listing on <img class="exchange" src="/images/exchanges/indodax/32x32.png"/>Indodax
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 10, 2020
#             </div>
# <div class="event" id="event32103">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32103" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-bitfinex-32103" id="cap32103">
#                         Listing on <img class="exchange" src="/images/exchanges/bitfinex/32x32.png"/>Bitfinex
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 7, 2020
#             </div>
# <div class="event" id="event32075">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue32075" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-cryptocom-32075" id="cap32075">
#                         Listing on <img class="exchange" src="/images/exchanges/crypto-com/32x32.png"/>Crypto.com
#                     </a>
# </h3>
# <div class="added">
#                     Added 4 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 3, 2020
#             </div>
# <div class="event" id="event31677">
# <div class="tool-events">
# <i class="fad fa-bolt" data-tooltip="Important event" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue31677" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type swap" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=17&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Swap">Swap</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-token-swap-31677" id="cap31677">
#                         Token Swap
#                     </a>
# </h3>
# <div class="added">
#                     Added 5 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 September 2, 2020
#             </div>
# <div class="event" id="event31912">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue31912" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type report" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=20&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Report">Report</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-progress-update-on-the-egld-token-swap-on-binance-31912" id="cap31912">
#                         Progress Update on the eGLD Token Swap on Binance
#                     </a>
# </h3>
# <div class="added">
#                     Added 5 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 August 24, 2020
#             </div>
# <div class="event" id="event31427">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue31427" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type ama" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=2&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="AMA">AMA</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-ama-on-telegram-31427" id="cap31427">
#                         AMA on <i class="fab fa-telegram"></i>Telegram
#                     </a>
# </h3>
# <div class="added">
#                     Added 5 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 August 18, 2020
#             </div>
# <div class="event" id="event31122">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue31122" type="hidden" value="0"/>
# ...
# </div>
# <h3>
# <a href="/en/event/elrond-egld-partnership-with-gdac-27978" id="cap27978">
#                         Partnership With GDAC
#                     </a>
# </h3>
# <div class="added">
#                     Added 9 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 April 30, 2020
#             </div>
# <div class="event" id="event27916">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue27916" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-savings-products-on-binance-27916" id="cap27916">
#                         Savings Products on <img class="exchange" src="/images/exchanges/binance/32x32.png"/>Binance
#                     </a>
# </h3>
# <div class="added">
#                     Added 9 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 Until March 31, 2020
#             </div>
# <div class="event" id="event26052">
# <div class="tool-events">
# </div>
# <input id="favValue26052" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-native-elrond-wallet-26052" id="cap26052">
#                         Native Elrond Wallet
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# <div class="event" id="event26053">
# <div class="tool-events">
# </div>
# <input id="favValue26053" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type update" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=19&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Update">Update</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-elrond-bootstrapping-phase-2-26053" id="cap26053">
#                         Elrond Bootstrapping Phase 2
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 March 20, 2020
#             </div>
# <div class="event" id="event27289">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue27289" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type contest" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=8&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Contest">Contest</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-battle-of-nodes-27289" id="cap27289">
#                         Battle of Nodes
#                     </a>
# </h3>
# <div class="added">
#                     Added 10 months ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 Until December 31, 2019
#             </div>
# <div class="event" id="event22707">
# <div class="tool-events">
# </div>
# <input id="favValue22707" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-mainnet-launch-22707" id="cap22707">
#                         Mainnet Launch
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 December 29, 2019
#             </div>
# <div class="event" id="event25577">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue25577" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type release" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=15&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Release">Release</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-launch-of-staking-process-25577" id="cap25577">
#                         Launch of Staking Process
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 December 6, 2019
#             </div>
# <div class="event" id="event25261">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue25261" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type ama" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=2&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="AMA">AMA</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-ama-on-twitter-25261" id="cap25261">
#                         AMA on <i class="fab fa-twitter"></i>Twitter
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 November 22, 2019
#             </div>
# <div class="event" id="event25068">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue25068" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type partnership" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=14&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Partnership">Partnership</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-partnership-with-everstake-25068" id="cap25068">
#                         Partnership With Everstake
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 November 3, 2019
#             </div>
# <div class="event" id="event24524">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue24524" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type conference" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=7&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Conference">Conference</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-blockchain-week-in-san-francisco-usa-24524" id="cap24524">
# <img alt="" class="flag flag-us" src="/images/blank.gif"/>Blockchain Week in San Francisco
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 October 23, 2019
#             </div>
# <div class="event" id="event24436">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue24436" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type ama" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=2&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="AMA">AMA</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-ama-on-periscope-24436" id="cap24436">
#                         AMA on <i class="fab fa-periscope"></i>Periscope
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 Until September 30, 2019
#             </div>
# <div class="event" id="event22681">
# <div class="tool-events">
# </div>
# <input id="favValue22681" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type test" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=18&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Test">Test</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-public-testnet-launch-22681" id="cap22681">
#                         Public Testnet Launch
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div><div class="day-cont"> <div class="day">
#                 August 20, 2019
#             </div>
# <div class="event" id="event23314">
# <div class="tool-events">
# <i class="fad fa-badge-check" data-tooltip="Reliable source" onmouseout="tooltip_del()" onmouseover="tooltip(this)"></i>
# </div>
# <input id="favValue23314" type="hidden" value="0"/>
# <div class="caption">
# <div class="tags">
# <a class="event-type exchange" href="/en/search?type=0&amp;text=&amp;start=2021-01-31&amp;end=2025-01-31&amp;tags=9&amp;hot=0&amp;rp=0&amp;fav=0&amp;coins=&amp;cap_from=0&amp;cap_to=600000000000&amp;vol_from=0&amp;vol_to=300000000000&amp;ex=&amp;sort=0&amp;order=0" title="Exchange">Exchange</a>
# </div>
# <h3>
# <a href="/en/event/elrond-egld-listing-on-bitmax-23314" id="cap23314">
#                         Listing on <img class="exchange" src="/images/exchanges/bitmax/32x32.png"/>BitMax
#                     </a>
# </h3>
# <div class="added">
#                     Added 1 year ago
#
#
#                 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </link></div>
# </div>
# <div class="popup-cont" id="popMedia">
# <div class="popup" onclick="event.stopPropagation()">
# <div class="popup-media" id="popupMedia">
# </div>
# </div>
# <div class="close">✕</div>
# </div>
# </div>
# <div class="cont last-cont" id="lastCont"></div>
# </div>
# <div id="bottomCont">
# <div class="block-break bottom-cont">
# <div class="bottom">
# <div class="block">
# <strong>About</strong>
# <a href="/en/page/contacts">Contact us</a>
# <a href="/en/page/press">Press about us</a>
# <a href="/en/page/privacy">Privacy policy </a>
# <a href="/en/page/terms">Terms of service</a>
# </div>
# <div class="block">
# <strong>Partnership</strong>
# <a href="/en/page/partners">Our partners</a>
# <a href="/en/page/conferences">Conferences</a>
# <a href="/en/page/cashback">Cashback</a>
# <a href="/en/special/digitalsummit2020"><i class="fa-fire fad"></i> Digital Summit 2020</a>
# </div>
# <div class="block">
# <strong>Representatives</strong>
# <a href="/en/representatives">Manage a coin</a>
# <a href="/en/page/add-coin">Add coin</a>
# <a href="/en/add">Add event</a>
# <a href="/en/article/community-management-expansion-into-new-markets-27571">Community management</a>
# <a href="/en/page/advertising">Advertising / Marketing</a>
# </div>
# <div class="block">
# <strong>Developers</strong>
# <a href="/en/api">API <span class="green">2.0</span></a>
# <a class="elem-hide" href="/en/api/widget">Website widget</a>
# </div>
# <div class="block social-block">
# <strong>Community</strong>
# <a class="a-menu-soc" href="tg://resolve?domain=coindar" target="_blank"><i class="fab fa-telegram"></i> <span>Telegram</span></a>
# <a class="a-menu-soc" href="tg://resolve?domain=coindar_blog" target="_blank"><i class="fab fa-telegram"></i> <span>Telegram (Blog)</span></a>
# <a class="a-menu-soc" href="https://twitter.com/coindar_" target="_blank"><i class="fab fa-twitter"></i> <span>Twitter</span></a>
# <a class="a-menu-soc" href="https://facebook.com/coindar" target="_blank"><i class="fab fa-facebook"></i> <span>Facebook</span></a>
# </div>
# </div>
# </div>
# <div class="copy" id="copyCont">
#             © 2020  <strong>Coindar</strong><br/>
# <a href="https://www.linkedin.com/in/yanhav/" target="_blank">Yan Khavanskiy</a>
# </div>
# </div>
# <div class="popup-cont" id="popAuth" onclick="hideAuth()">
# <div class="auth" onclick="event.stopPropagation()">
# <div class="login">
# <a href="/en/account/auth/twitter?url=https://coindar.org/en/coin/elrond"><img alt="twitter" src="/images/social/twitter_m.png"/></a>
# <a href="/en/account/auth/facebook?url=https://coindar.org/en/coin/elrond"><img alt="facebook" src="/images/social/facebook_m.png"/></a>
# <a href="/en/account/auth/google?url=https://coindar.org/en/coin/elrond"><img alt="google" src="/images/social/google_m.png"/></a>
# <a href="/en/account/auth/vk?url=https://coindar.org/en/coin/elrond"><img alt="vk" src="/images/social/vk_m.png"/></a>
# <a href="/en/account/signin?url=https://coindar.org/en/coin/elrond"><img alt="coindar" src="/images/social/coindar_m.png"/></a>
# </div>
# <div class="license">
#                 By authorising, you accepting <a href="/en/page/terms">the terms of use</a> and agree that we can process your <a href="/en/page/privacy">private information</a>.
#             </div>
# </div>
# <div class="close">✕</div>
# </div>
# <script src="/Scripts/modernizr-2.8.3.js"></script>
# <script src="/Scripts/jquery-3.3.1.min.js"></script>
# <script src="/scripts/jquery.cookie-1.4.1.min.js"></script>
# <script src="/Scripts/jquery.validate.js"></script>
# <script src="/Scripts/jquery.validate.unobtrusive.js"></script>
# <script src="/scripts/jquery.unobtrusive-ajax.min.js"></script>
# <script>
#         var isAuthState = false;
#         var is_mob = false;
#         var is_ios = false;
#         var is_dark = false;
#         var mode_dark = 'Dark mode';
#         var mode_light = 'Light mode';
#         var cur_lang = 'en';
#     </script>
# <script>
#         if ('serviceWorker' in navigator) {
#             navigator.serviceWorker.register('/service-worker.js')
#                 .then(function (reg) {
#                 }).catch(function (err) {
#                 });
#         }
#     </script>
# <script src="/js/desktop.js"></script>
# <script src="/JS/chart.js"></script>
# <script type="text/javascript">
#         var language = 'en';
#         var trade_vol = '24 hour trade volume';
#     </script>
# <script src="/js/coin.js"></script>
# <script src="/js/events_total.js"></script>
# </body>
# </html>

# %%
script = soup.find('script', {'type' : 'text/javascript'})
script
# Out:
# <script type="text/javascript">
#         var chartData = [{'date': new Date(2021,01-1,31), 'value': 63.830000000}];
#         var chartEvents = [{'date': new Date(2021,01-1,07), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Gate.io', 'url': '/en/event/elrond-egld-listing-on-gateio-36562'},{'date': new Date(2020,12-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on eToroX', 'url': '/en/event/elrond-egld-listing-on-etorox-35004'},{'date': new Date(2020,10-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Tokocrypto', 'url': '/en/event/elrond-egld-listing-on-tokocrypto-33412'},{'date': new Date(2020,10-1,16), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'EGLD & CNTR Rewards Distribution', 'url': '/en/event/elrond-egld-egld-cntr-rewards-distribution-32947'},{'date': new Date(2020,10-1,12), 'type': 'text', 'backgroundColor': '#bab57e', 'borderColor': '#bab57e', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#ada873', 'text': 'Report', 'description': 'Weekly Development Update', 'url': '/en/event/elrond-egld-weekly-development-update-33130'},{'date': new Date(2020,10-1,08), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32997'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Binance Savings Staking', 'url': '/en/event/elrond-egld-binance-savings-staking-32949'},{'date': new Date(2020,09-1,30), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32840'},{'date': new Date(2020,09-1,30), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32851'},{'date': new Date(2020,09-1,24), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Binance.US', 'url': '/en/event/elrond-egld-listing-on-binanceus-32610'},{'date': new Date(2020,09-1,24), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32618'},{'date': new Date(2020,09-1,22), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Bithumb Global', 'url': '/en/event/elrond-egld-listing-on-bithumb-global-31428'},{'date': new Date(2020,09-1,22), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Bithumb Global', 'url': '/en/event/elrond-egld-listing-on-bithumb-global-32564'},{'date': new Date(2020,09-1,16), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Sistemkoin', 'url': '/en/event/elrond-egld-listing-on-sistemkoin-32390'},{'date':  ...
#         var chartEvents_pub = [{'date': new Date(2021,01-1,07), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Gate.io', 'url': '/en/event/elrond-egld-listing-on-gateio-36562'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'DeFi Initiatives', 'url': '/en/event/elrond-egld-defi-initiatives-30212'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Privacy Research', 'url': '/en/event/elrond-egld-privacy-research-30213'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Blockchain Interoperability', 'url': '/en/event/elrond-egld-blockchain-interoperability-30214'},{'date': new Date(2020,12-1,16), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on eToroX', 'url': '/en/event/elrond-egld-listing-on-etorox-35004'},{'date': new Date(2020,10-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Tokocrypto', 'url': '/en/event/elrond-egld-listing-on-tokocrypto-33412'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'EGLD & CNTR Rewards Distribution', 'url': '/en/event/elrond-egld-egld-cntr-rewards-distribution-32947'},{'date': new Date(2020,10-1,12), 'type': 'text', 'backgroundColor': '#bab57e', 'borderColor': '#bab57e', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#ada873', 'text': 'Report', 'description': 'Weekly Development Update', 'url': '/en/event/elrond-egld-weekly-development-update-33130'},{'date': new Date(2020,10-1,07), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32997'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Binance Savings Staking', 'url': '/en/event/elrond-egld-binance-savings-staking-32949'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#8cbf80', 'borderColor': '#8cbf80', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7db072', 'text': 'Release', 'description': 'Elrond dApp Store', 'url': '/en/event/elrond-egld-elrond-dapp-store-29938'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#c3c27c', 'borderColor': '#c3c27c', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b7b672', 'text': 'Update', 'description': 'Elrond Digital Identity', 'url': '/en/event/elrond-egld-elrond-digital-identity-30210'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#8cbf80', 'borderColor': '#8cbf80', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7db072', 'text': 'Release', 'description': 'Name Service', 'url': '/en/event/elrond-egld-name-service-30211'},{'date': new Date(2020,09-1,29), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32840'},{'date': new Date(2020,09-1,29 ...
# </script>

# %%
script
# Out:
# <script type="text/javascript">
#         var chartData = [{'date': new Date(2021,01-1,31), 'value': 63.830000000}];
#         var chartEvents = [{'date': new Date(2021,01-1,07), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Gate.io', 'url': '/en/event/elrond-egld-listing-on-gateio-36562'},{'date': new Date(2020,12-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on eToroX', 'url': '/en/event/elrond-egld-listing-on-etorox-35004'},{'date': new Date(2020,10-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Tokocrypto', 'url': '/en/event/elrond-egld-listing-on-tokocrypto-33412'},{'date': new Date(2020,10-1,16), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'EGLD & CNTR Rewards Distribution', 'url': '/en/event/elrond-egld-egld-cntr-rewards-distribution-32947'},{'date': new Date(2020,10-1,12), 'type': 'text', 'backgroundColor': '#bab57e', 'borderColor': '#bab57e', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#ada873', 'text': 'Report', 'description': 'Weekly Development Update', 'url': '/en/event/elrond-egld-weekly-development-update-33130'},{'date': new Date(2020,10-1,08), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32997'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Binance Savings Staking', 'url': '/en/event/elrond-egld-binance-savings-staking-32949'},{'date': new Date(2020,09-1,30), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32840'},{'date': new Date(2020,09-1,30), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32851'},{'date': new Date(2020,09-1,24), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Binance.US', 'url': '/en/event/elrond-egld-listing-on-binanceus-32610'},{'date': new Date(2020,09-1,24), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32618'},{'date': new Date(2020,09-1,22), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Bithumb Global', 'url': '/en/event/elrond-egld-listing-on-bithumb-global-31428'},{'date': new Date(2020,09-1,22), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Bithumb Global', 'url': '/en/event/elrond-egld-listing-on-bithumb-global-32564'},{'date': new Date(2020,09-1,16), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Sistemkoin', 'url': '/en/event/elrond-egld-listing-on-sistemkoin-32390'},{'date':  ...
#         var chartEvents_pub = [{'date': new Date(2021,01-1,07), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Gate.io', 'url': '/en/event/elrond-egld-listing-on-gateio-36562'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'DeFi Initiatives', 'url': '/en/event/elrond-egld-defi-initiatives-30212'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Privacy Research', 'url': '/en/event/elrond-egld-privacy-research-30213'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Blockchain Interoperability', 'url': '/en/event/elrond-egld-blockchain-interoperability-30214'},{'date': new Date(2020,12-1,16), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on eToroX', 'url': '/en/event/elrond-egld-listing-on-etorox-35004'},{'date': new Date(2020,10-1,23), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on Tokocrypto', 'url': '/en/event/elrond-egld-listing-on-tokocrypto-33412'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'EGLD & CNTR Rewards Distribution', 'url': '/en/event/elrond-egld-egld-cntr-rewards-distribution-32947'},{'date': new Date(2020,10-1,12), 'type': 'text', 'backgroundColor': '#bab57e', 'borderColor': '#bab57e', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#ada873', 'text': 'Report', 'description': 'Weekly Development Update', 'url': '/en/event/elrond-egld-weekly-development-update-33130'},{'date': new Date(2020,10-1,07), 'type': 'text', 'backgroundColor': '#a3bd53', 'borderColor': '#a3bd53', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#99b150', 'text': 'AMA', 'description': 'AMA on Periscope', 'url': '/en/event/elrond-egld-ama-on-periscope-32997'},{'date': new Date(2020,10-1,04), 'type': 'text', 'backgroundColor': '#7d93cf', 'borderColor': '#7d93cf', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7087c7', 'text': 'General', 'description': 'Binance Savings Staking', 'url': '/en/event/elrond-egld-binance-savings-staking-32949'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#8cbf80', 'borderColor': '#8cbf80', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7db072', 'text': 'Release', 'description': 'Elrond dApp Store', 'url': '/en/event/elrond-egld-elrond-dapp-store-29938'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#c3c27c', 'borderColor': '#c3c27c', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b7b672', 'text': 'Update', 'description': 'Elrond Digital Identity', 'url': '/en/event/elrond-egld-elrond-digital-identity-30210'},{'date': new Date(2020,07-1,18), 'type': 'text', 'backgroundColor': '#8cbf80', 'borderColor': '#8cbf80', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#7db072', 'text': 'Release', 'description': 'Name Service', 'url': '/en/event/elrond-egld-name-service-30211'},{'date': new Date(2020,09-1,29), 'type': 'text', 'backgroundColor': '#c39576', 'borderColor': '#c39576', 'color': '#fff', 'graph': 'g1', 'rollOverColor': '#b78c6e', 'text': 'Exchange', 'description': 'Listing on OKEx', 'url': '/en/event/elrond-egld-listing-on-okex-32840'},{'date': new Date(2020,09-1,29 ...
# </script>

# %%
json.loads(script.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-60a5ee56119d> in <module>
# ----> 1 json.loads(script.text)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
all_data = ev_list_sec['data-chart']
event_date = ev_list_sec['data-event']
